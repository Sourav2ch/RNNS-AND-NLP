# %%
import torch
import os
import torch.nn as nn
import numpy as np
from torch.nn.utils import clip_grad_norm

# %%
class Dictionary(object):
    def __init__(self):
        self.word2idx = {}
        self.idx2word = {}
        self.idx = 0

    def add_word(self, word):
        if word not in self.word2idx:
            self.word2idx[word] = self.idx
            self.idx2word[self.idx] = word
            self.idx += 1
            
    def __len__(self):
        return len(self.word2idx)

# %%
class TextProcess(object):
    
    def __init__(self):
        self.dictionary = Dictionary()

    def get_data(self, path, batch_size=20):
        with open(path, 'r') as f:
            tokens = 0
            for line in f:
                words = line.split() + ['<eos>']
                tokens += len(words)
                for word in words: 
                    self.dictionary.add_word(word)  
        #Create a 1-D tensor that contains the index of all the words in the file
        rep_tensor = torch.LongTensor(tokens)
        index = 0
        with open(path, 'r') as f:
            for line in f:
                words = line.split() + ['<eos>']
                for word in words:
                    rep_tensor[index] = self.dictionary.word2idx[word]
                    index += 1
        #Find out how many batches we need            
        num_batches = rep_tensor.shape[0] // batch_size     
        #Remove the remainder (Filter out the ones that don't fit)
        rep_tensor = rep_tensor[:num_batches*batch_size]
        # return (batch_size,num_batches)
        rep_tensor = rep_tensor.view(batch_size, -1)
        return rep_tensor

# %%
embed_size = 128    #Input features to the LSTM
hidden_size = 1024  #Number of LSTM units
num_layers = 1
num_epochs = 20
batch_size = 20
timesteps = 30
learning_rate = 0.002

# %%
corpus = TextProcess()

# %%
rep_tensor = corpus.get_data('alice.txt', batch_size)

# %%
#rep_tensor is the tensor that contains the index of all the words. Each row contains 1659 words by default 
print(rep_tensor.shape)
# Out:
# torch.Size([20, 1484])

# %%
vocab_size = len(corpus.dictionary)
print(vocab_size)
# Out:
# 5290

# %%
num_batches = rep_tensor.shape[1] // timesteps
print(num_batches)
# Out:
# 49

# %%
class TextGenerator(nn.Module):
    
    def __init__(self, vocab_size, embed_size, hidden_size, num_layers):
        super(TextGenerator, self).__init__()
        self.embed = nn.Embedding(vocab_size, embed_size)
        self.lstm = nn.LSTM(embed_size, hidden_size, num_layers, batch_first=True)
        self.linear = nn.Linear(hidden_size, vocab_size)

    def forward(self, x, h):
        # Perform Word Embedding 
        x = self.embed(x)
        #Reshape the input tensor
        #x = x.view(batch_size,timesteps,embed_size)
        out, (h, c) = self.lstm(x, h)
        # Reshape the output from (samples,timesteps,output_features) to a shape appropriate for the FC layer 
        # (batch_size*timesteps, hidden_size)
        out = out.reshape(out.size(0)*out.size(1), out.size(2))
        # Decode hidden states of all time steps
        out = self.linear(out)
        return out, (h, c)

# %%
model = TextGenerator(vocab_size, embed_size, hidden_size, num_layers)

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
def detach(states):
    """
If we have a tensor z,'z.detach()' returns a tensor that shares the same storage
as 'z', but with the computation history forgotten. It doesn't know anything
about how it was computed. In other words, we have broken the tensor z away from its past history
Here, we want to perform truncated Backpropagation
TBPTT splits the 1,000-long sequence into 50 sequences (say) each of length 20 and treats each sequence of length 20 as 
a separate training case. This is a sensible approach that can work well in practice, but it is blind to temporal 
dependencies that span more than 20 timesteps.
    """
    return [state.detach() for state in states]

# %%
for epoch in range(num_epochs):
    # Set initial hidden and cell states
    states = (torch.zeros(num_layers, batch_size, hidden_size),
              torch.zeros(num_layers, batch_size, hidden_size))

    for i in range(0, rep_tensor.size(1) - timesteps, timesteps):
        # Get mini-batch inputs and targets
        inputs = rep_tensor[:, i:i+timesteps]  
        targets = rep_tensor[:, (i+1):(i+1)+timesteps]
        
        outputs,_ = model(inputs, states)
        loss = loss_fn(outputs, targets.reshape(-1))

        model.zero_grad()
        loss.backward()
        #Perform Gradient Clipping. clip_value (float or int) is the maximum allowed value of the gradients 
        #The gradients are clipped in the range [-clip_value, clip_value]. This is to prevent the exploding gradient problem
        clip_grad_norm(model.parameters(), 0.5)
        optimizer.step()
              
        step = (i+1) // timesteps
        if step % 100 == 0:
            print ('Epoch [{}/{}], Loss: {:.4f}'
                   .format(epoch+1, num_epochs, loss.item()))
# Out:
# C:\Users\SOURAV CH\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
# Epoch [1/20], Loss: 8.5740
# Epoch [2/20], Loss: 5.9278
# Epoch [3/20], Loss: 5.3075
# Epoch [4/20], Loss: 4.7422
# Epoch [5/20], Loss: 4.1775
# Epoch [6/20], Loss: 3.7135
# Epoch [7/20], Loss: 3.3028
# Epoch [8/20], Loss: 2.8779
# Epoch [9/20], Loss: 2.4352
# Epoch [10/20], Loss: 2.0585
# Epoch [11/20], Loss: 1.8136
# Epoch [12/20], Loss: 1.4468
# Epoch [13/20], Loss: 1.1963
# Epoch [14/20], Loss: 0.9798
# Epoch [15/20], Loss: 0.6974
# Epoch [16/20], Loss: 0.4929
# Epoch [17/20], Loss: 0.3272
# Epoch [18/20], Loss: 0.2155
# Epoch [19/20], Loss: 0.1184
# Epoch [20/20], Loss: 0.0839

# %%
# Test the model
with torch.no_grad():
    with open('results.txt', 'w') as f:
        # Set intial hidden ane cell states
        state = (torch.zeros(num_layers, 1, hidden_size),
                 torch.zeros(num_layers, 1, hidden_size))
        # Select one word id randomly and convert it to shape (1,1)
        input = torch.randint(0,vocab_size, (1,)).long().unsqueeze(1)

        for i in range(500):
            output, _ = model(input, state)
            print(output.shape)
            # Sample a word id from the exponential of the output 
            prob = output.exp()
            word_id = torch.multinomial(prob, num_samples=1).item()
            print(word_id)
            # Replace the input with sampled word id for the next time step
            input.fill_(word_id)

            # Write the results to file
            word = corpus.dictionary.idx2word[word_id]
            word = '\n' if word == '<eos>' else word + ' '
            f.write(word)
            
            if (i+1) % 100 == 0:
                print('Sampled [{}/{}] words and save to {}'.format(i+1, 500, 'results.txt'))
# Out:
# torch.Size([1, 5290])
# 34
# torch.Size([1, 5290])
# 7
# torch.Size([1, 5290])
# 22
# torch.Size([1, 5290])
# 28
# torch.Size([1, 5290])
# 150
# torch.Size([1, 5290])
# 114
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 2065
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 1767
# torch.Size([1, 5290])
# 1343
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 160
# torch.Size([1, 5290])
# 6
# torch.Size([1, 5290])
# 333
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 1117
# torch.Size([1, 5290])
# 103
# torch.Size([1, 5290])
# 4924
# torch.Size([1, 5290])
# 28
# torch.Size([1, 5290])
# 150
# torch.Size([1, 5290])
# 114
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 4772
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 439
# torch.Size([1, 5290])
# 209
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 4188
# torch.Size([1, 5290])
# 861
# torch.Size([1, 5290])
# 2882
# torch.Size([1, 5290])
# 20
# torch.Size([1, 5290])
# 6
# torch.Size([1, 5290])
# 333
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 426
# torch.Size([1, 5290])
# 7
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 43
# torch.Size([1, 5290])
# 117
# torch.Size([1, 5290])
# 60
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 6
# torch.Size([1, 5290])
# 129
# torch.Size([1, 5290])
# 300
# torch.Size([1, 5290])
# 38
# torch.Size([1, 5290])
# 207
# torch.Size([1, 5290])
# 137
# torch.Size([1, 5290])
# 485
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 603
# torch.Size([1, 5290])
# 116
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 303
# torch.Size([1, 5290])
# 787
# torch.Size([1, 5290])
# 691
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 3779
# torch.Size([1, 5290])
# 3280
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 3027
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 2665
# torch.Size([1, 5290])
# 4485
# torch.Size([1, 5290])
# 20
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 1697
# torch.Size([1, 5290])
# 7
# torch.Size([1, 5290])
# 300
# torch.Size([1, 5290])
# 285
# torch.Size([1, 5290])
# 691
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 4772
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 1054
# torch.Size([1, 5290])
# 2183
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 3726
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 27
# torch.Size([1, 5290])
# 916
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 3038
# torch.Size([1, 5290])
# 20
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 1040
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 5234
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 1616
# torch.Size([1, 5290])
# 13
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 4772
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 303
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 3679
# Sampled [100/500] words and save to results.txt
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 2836
# torch.Size([1, 5290])
# 35
# torch.Size([1, 5290])
# 2678
# torch.Size([1, 5290])
# 1001
# torch.Size([1, 5290])
# 103
# torch.Size([1, 5290])
# 855
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 776
# torch.Size([1, 5290])
# 103
# torch.Size([1, 5290])
# 309
# torch.Size([1, 5290])
# 87
# torch.Size([1, 5290])
# 27
# torch.Size([1, 5290])
# 28
# torch.Size([1, 5290])
# 44
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 668
# torch.Size([1, 5290])
# 970
# torch.Size([1, 5290])
# 42
# torch.Size([1, 5290])
# 80
# torch.Size([1, 5290])
# 1054
# torch.Size([1, 5290])
# 95
# torch.Size([1, 5290])
# 44
# torch.Size([1, 5290])
# 4441
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 366
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 426
# torch.Size([1, 5290])
# 7
# torch.Size([1, 5290])
# 22
# torch.Size([1, 5290])
# 28
# torch.Size([1, 5290])
# 44
# torch.Size([1, 5290])
# 2986
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 367
# torch.Size([1, 5290])
# 134
# torch.Size([1, 5290])
# 18
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 5234
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 937
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 3225
# torch.Size([1, 5290])
# 9
# torch.Size([1, 5290])
# 1471
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 518
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 836
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 5234
# torch.Size([1, 5290])
# 114
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 96
# torch.Size([1, 5290])
# 1274
# torch.Size([1, 5290])
# 167
# torch.Size([1, 5290])
# 727
# torch.Size([1, 5290])
# 4555
# torch.Size([1, 5290])
# 238
# torch.Size([1, 5290])
# 44
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 6
# torch.Size([1, 5290])
# 38
# torch.Size([1, 5290])
# 16
# torch.Size([1, 5290])
# 38
# torch.Size([1, 5290])
# 1617
# torch.Size([1, 5290])
# 103
# torch.Size([1, 5290])
# 4924
# torch.Size([1, 5290])
# 427
# torch.Size([1, 5290])
# 11
# torch.Size([1, 5290])
# 1667
# torch.Size([1, 5290])
# 1770
# torch.Size([1, 5290])
# 1054
# torch.Size([1, 5290])
# 4185
# torch.Size([1, 5290])
# 1756
# torch.Size([1, 5290])
# 110
# torch.Size([1, 5290])
# 2423
# torch.Size([1, 5290])
# 272
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 3788
# torch.Size([1, 5290])
# 851
# torch.Size([1, 5290])
# 601
# torch.Size([1, 5290])
# 402
# torch.Size([1, 5290])
# 403
# torch.Size([1, 5290])
# 44
# torch.Size([1, 5290])
# 367
# torch.Size([1, 5290])
# 4204
# torch.Size([1, 5290])
# 338
# torch.Size([1, 5290])
# 76
# torch.Size([1, 5290])
# 103
# torch.Size([1, 5290])
# 843
# torch.Size([1, 5290])
# 627
# torch.Size([1, 5290])
# 628
# torch.Size([1, 5290])
# 3581
# Sampled [200/500] words and save to results.txt
# torch.Size([1, 5290])
# 20
# torch.Size([1, 5290])
# 203
# torch.Size([1, 5290])
# 3546
# torch.Size([1, 5290])
# 9
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 1215
# torch.Size([1, 5290])
# 202
# torch.Size([1, 5290])
# 491
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 768
# torch.Size([1, 5290])
# 1238
# torch.Size([1, 5290])
# 3742
# torch.Size([1, 5290])
# 38
# torch.Size([1, 5290])
# 44
# torch.Size([1, 5290])
# 3091
# torch.Size([1, 5290])
# 3757
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 5234
# torch.Size([1, 5290])
# 114
# torch.Size([1, 5290])
# 1649
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 1237
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 3197
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 552
# torch.Size([1, 5290])
# 4639
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 836
# torch.Size([1, 5290])
# 7
# torch.Size([1, 5290])
# 44
# torch.Size([1, 5290])
# 1228
# torch.Size([1, 5290])
# 272
# torch.Size([1, 5290])
# 6
# torch.Size([1, 5290])
# 649
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 4262
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 3830
# torch.Size([1, 5290])
# 34
# torch.Size([1, 5290])
# 2430
# torch.Size([1, 5290])
# 95
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 265
# torch.Size([1, 5290])
# 787
# torch.Size([1, 5290])
# 1001
# torch.Size([1, 5290])
# 103
# torch.Size([1, 5290])
# 408
# torch.Size([1, 5290])
# 1001
# torch.Size([1, 5290])
# 41
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 1054
# torch.Size([1, 5290])
# 2183
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 3788
# torch.Size([1, 5290])
# 20
# torch.Size([1, 5290])
# 34
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 1237
# torch.Size([1, 5290])
# 110
# torch.Size([1, 5290])
# 251
# torch.Size([1, 5290])
# 103
# torch.Size([1, 5290])
# 402
# torch.Size([1, 5290])
# 403
# torch.Size([1, 5290])
# 44
# torch.Size([1, 5290])
# 2243
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 80
# torch.Size([1, 5290])
# 1054
# torch.Size([1, 5290])
# 2183
# torch.Size([1, 5290])
# 6
# torch.Size([1, 5290])
# 7
# torch.Size([1, 5290])
# 173
# torch.Size([1, 5290])
# 4451
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 9
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 512
# torch.Size([1, 5290])
# 20
# torch.Size([1, 5290])
# 7
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 5234
# torch.Size([1, 5290])
# 38
# torch.Size([1, 5290])
# 1617
# torch.Size([1, 5290])
# 103
# torch.Size([1, 5290])
# 3307
# torch.Size([1, 5290])
# 27
# torch.Size([1, 5290])
# 28
# torch.Size([1, 5290])
# 44
# torch.Size([1, 5290])
# 1228
# torch.Size([1, 5290])
# 1737
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 3779
# torch.Size([1, 5290])
# 98
# torch.Size([1, 5290])
# 9
# Sampled [300/500] words and save to results.txt
# torch.Size([1, 5290])
# 262
# torch.Size([1, 5290])
# 95
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 6
# torch.Size([1, 5290])
# 7
# torch.Size([1, 5290])
# 173
# torch.Size([1, 5290])
# 114
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 27
# torch.Size([1, 5290])
# 5269
# torch.Size([1, 5290])
# 272
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 915
# torch.Size([1, 5290])
# 265
# torch.Size([1, 5290])
# 787
# torch.Size([1, 5290])
# 1001
# torch.Size([1, 5290])
# 41
# torch.Size([1, 5290])
# 42
# torch.Size([1, 5290])
# 9
# torch.Size([1, 5290])
# 615
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 943
# torch.Size([1, 5290])
# 317
# torch.Size([1, 5290])
# 9
# torch.Size([1, 5290])
# 98
# torch.Size([1, 5290])
# 34
# torch.Size([1, 5290])
# 7
# torch.Size([1, 5290])
# 173
# torch.Size([1, 5290])
# 945
# torch.Size([1, 5290])
# 13
# torch.Size([1, 5290])
# 1054
# torch.Size([1, 5290])
# 4185
# torch.Size([1, 5290])
# 103
# torch.Size([1, 5290])
# 28
# torch.Size([1, 5290])
# 35
# torch.Size([1, 5290])
# 2678
# torch.Size([1, 5290])
# 272
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 1933
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 1625
# torch.Size([1, 5290])
# 27
# torch.Size([1, 5290])
# 309
# torch.Size([1, 5290])
# 87
# torch.Size([1, 5290])
# 27
# torch.Size([1, 5290])
# 265
# torch.Size([1, 5290])
# 1909
# torch.Size([1, 5290])
# 202
# torch.Size([1, 5290])
# 491
# torch.Size([1, 5290])
# 207
# torch.Size([1, 5290])
# 1420
# torch.Size([1, 5290])
# 285
# torch.Size([1, 5290])
# 3301
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 3726
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 4513
# torch.Size([1, 5290])
# 1062
# torch.Size([1, 5290])
# 27
# torch.Size([1, 5290])
# 28
# torch.Size([1, 5290])
# 44
# torch.Size([1, 5290])
# 1365
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 80
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 1312
# torch.Size([1, 5290])
# 9
# torch.Size([1, 5290])
# 552
# torch.Size([1, 5290])
# 483
# torch.Size([1, 5290])
# 34
# torch.Size([1, 5290])
# 55
# torch.Size([1, 5290])
# 27
# torch.Size([1, 5290])
# 272
# torch.Size([1, 5290])
# 34
# torch.Size([1, 5290])
# 463
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 3832
# torch.Size([1, 5290])
# 13
# torch.Size([1, 5290])
# 1552
# torch.Size([1, 5290])
# 38
# torch.Size([1, 5290])
# 80
# torch.Size([1, 5290])
# 1351
# torch.Size([1, 5290])
# 202
# torch.Size([1, 5290])
# 491
# torch.Size([1, 5290])
# 304
# torch.Size([1, 5290])
# 777
# torch.Size([1, 5290])
# 272
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 2065
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 1457
# Sampled [400/500] words and save to results.txt
# torch.Size([1, 5290])
# 3607
# torch.Size([1, 5290])
# 13
# torch.Size([1, 5290])
# 1585
# torch.Size([1, 5290])
# 114
# torch.Size([1, 5290])
# 1649
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 413
# torch.Size([1, 5290])
# 9
# torch.Size([1, 5290])
# 236
# torch.Size([1, 5290])
# 265
# torch.Size([1, 5290])
# 1909
# torch.Size([1, 5290])
# 202
# torch.Size([1, 5290])
# 491
# torch.Size([1, 5290])
# 483
# torch.Size([1, 5290])
# 16
# torch.Size([1, 5290])
# 2756
# torch.Size([1, 5290])
# 320
# torch.Size([1, 5290])
# 74
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 4772
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 265
# torch.Size([1, 5290])
# 1909
# torch.Size([1, 5290])
# 202
# torch.Size([1, 5290])
# 491
# torch.Size([1, 5290])
# 20
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 160
# torch.Size([1, 5290])
# 6
# torch.Size([1, 5290])
# 44
# torch.Size([1, 5290])
# 367
# torch.Size([1, 5290])
# 4204
# torch.Size([1, 5290])
# 1440
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 915
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 3204
# torch.Size([1, 5290])
# 107
# torch.Size([1, 5290])
# 329
# torch.Size([1, 5290])
# 330
# torch.Size([1, 5290])
# 367
# torch.Size([1, 5290])
# 4204
# torch.Size([1, 5290])
# 564
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 600
# torch.Size([1, 5290])
# 362
# torch.Size([1, 5290])
# 69
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 3968
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 2344
# torch.Size([1, 5290])
# 217
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 191
# torch.Size([1, 5290])
# 27
# torch.Size([1, 5290])
# 28
# torch.Size([1, 5290])
# 150
# torch.Size([1, 5290])
# 114
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 1051
# torch.Size([1, 5290])
# 20
# torch.Size([1, 5290])
# 6
# torch.Size([1, 5290])
# 44
# torch.Size([1, 5290])
# 367
# torch.Size([1, 5290])
# 4204
# torch.Size([1, 5290])
# 339
# torch.Size([1, 5290])
# 340
# torch.Size([1, 5290])
# 9
# torch.Size([1, 5290])
# 262
# torch.Size([1, 5290])
# 95
# torch.Size([1, 5290])
# 13
# torch.Size([1, 5290])
# 1585
# torch.Size([1, 5290])
# 20
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 4900
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 757
# torch.Size([1, 5290])
# 3
# torch.Size([1, 5290])
# 4008
# torch.Size([1, 5290])
# 4168
# torch.Size([1, 5290])
# 44
# torch.Size([1, 5290])
# 282
# torch.Size([1, 5290])
# 1663
# torch.Size([1, 5290])
# 9
# torch.Size([1, 5290])
# 552
# torch.Size([1, 5290])
# 4639
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 943
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 16
# torch.Size([1, 5290])
# 390
# torch.Size([1, 5290])
# 13
# torch.Size([1, 5290])
# 1552
# torch.Size([1, 5290])
# 5
# torch.Size([1, 5290])
# 798
# torch.Size([1, 5290])
# 39
# torch.Size([1, 5290])
# 13
# torch.Size([1, 5290])
# 1585
# torch.Size([1, 5290])
# 20
# Sampled [500/500] words and save to results.txt
